# %%
import numpy as np
arr = [[1, 0, 0],
       [0, 1, 0],
       [0, 0, 1],
       [1, 0, 0]]
arr = np.array(arr)
arr1 = np.zeros((2, 2))
arr1 = np.all(arr == [0, 1, 0], axis = 1)
print(arr1)
# Out:
# [False  True False False]

# %%
import numpy as np
arr = np.array([
    [1, 0, 0],
    [0, 1, 0],
    [0, 0, 1]
])
np.sum(arr)
# Out:
# 3

# %%
np.product(arr.shape)
# Out:
# 9

# %%
import numpy as np
A = 2 * np.ones((2, 3))
B = 3 * np.ones((2, 3))
print(A * B)
# Out:
# [[6. 6. 6.]
#  [6. 6. 6.]]

# %%
A = np.ones((2, 3, 4))
np.mean(A, axis = (1, 2))
# Out:
# array([1., 1.])

# %%
import numpy as np
A = np.ones((2, 3))
np.where(A >= 0, -1, 1)
# Out:
# array([[-1, -1, -1],
#        [-1, -1, -1]])

# %%
from matplotlib import pyplot as plt
import numpy as np

A = np.array([
    [0., 0., 1.],
    [0., 1., 1.],
    [1., 1., 0.]
])
plt.figure()
plt.imshow(A, cmap = 'gray')
plt.show()

# %%
import numpy as np

A = np.array([
    [1, 2],
    [3, 4]
])
B = np.array([
    [5, 6],
    [7, 8]
])
print(A * B)
# Out:
# [[ 5 12]
#  [21 32]]
